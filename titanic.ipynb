# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df.Embarked.fillna(df.Embarked.mode()[0],inplace = True)

# %%
df.Embarked.isna().sum()
# Out:
# 0

# %%
print (df[df['Embarked'] == 'S'].shape)
print (df[df['Embarked'] == 'C'].shape)
print (df[df['Embarked'] == 'Q'].shape)
# Out:
# (646, 12)
# (168, 12)
# (77, 12)

# %%
newdf = df.drop(columns=['PassengerId','Survived','Pclass','SibSp','Name','Ticket','Cabin'])

# %%
newdf
# Out:
#         Sex   Age  Parch     Fare Embarked
# 0      male  22.0      0   7.2500        S
# 1    female  38.0      0  71.2833        C
# 2    female  26.0      0   7.9250        S
# 3    female  35.0      0  53.1000        S
# 4      male  35.0      0   8.0500        S
# ..      ...   ...    ...      ...      ...
# 886    male  27.0      0  13.0000        S
# 887  female  19.0      0  30.0000        S
# 888  female   NaN      2  23.4500        S
# 889    male  26.0      0  30.0000        C
# 890    male  32.0      0   7.7500        Q
#
# [891 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
dum = pd.get_dummies(newdf,dtype=int)

# %%
dum
# Out:
#       Age  Parch     Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0    22.0      0   7.2500           0         1           0           0
# 1    38.0      0  71.2833           1         0           1           0
# 2    26.0      0   7.9250           1         0           0           0
# 3    35.0      0  53.1000           1         0           0           0
# 4    35.0      0   8.0500           0         1           0           0
# ..    ...    ...      ...         ...       ...         ...         ...
# 886  27.0      0  13.0000           0         1           0           0
# 887  19.0      0  30.0000           1         0           0           0
# 888   0.0      2  23.4500           1         0           0           0
# 889  26.0      0  30.0000           0         1           1           0
# 890  32.0      0   7.7500           0         1           0           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# ...

# %%
x1 = dum
y1 = df['Survived']

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x1,y1)
# Out:
# DecisionTreeClassifier()

# %%
newdf.isna().sum()
# Out:
# Sex         0
# Age         0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df['Age']=df['Age'].fillna(0)
df['Cabin']=df['Cabin'].fillna(0)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
x1
# Out:
#       Age  Parch     Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0    22.0      0   7.2500           0         1           0           0
# 1    38.0      0  71.2833           1         0           1           0
# 2    26.0      0   7.9250           1         0           0           0
# 3    35.0      0  53.1000           1         0           0           0
# 4    35.0      0   8.0500           0         1           0           0
# ..    ...    ...      ...         ...       ...         ...         ...
# 886  27.0      0  13.0000           0         1           0           0
# 887  19.0      0  30.0000           1         0           0           0
# 888   0.0      2  23.4500           1         0           0           0
# 889  26.0      0  30.0000           0         1           1           0
# 890  32.0      0   7.7500           0         1           0           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# ...

# %%
a = int(input("Age: "))
b = int(input("Parch: "))
c = float(input("fare: "))
d = input("Gender: ")
j = input("embarked: ")
e=0
f=0
g=0
h=0
i=0
if(d == "MALE" or "male"):
    e,f = 0,1
elif(d == "FEMALE" or "female"):
    e,f = 1,0
if(j == "C"):
    g,h,i=1,0,0
if(j == "Q"):
    g,h,i=0,1,0
if(j == "S"):
    g,h,i=0,0,1
k = model.predict([[a,b,c,e,f,g,h,i]])[0]
if(k == 0):
    print("died")
if(k == 1):
    print("Survied")
# Out:
# Age: 18
# Parch: 1
# fare: 82.333
# Gender: male
# embarked: Q
# died

# %%
model.score(x1,y1)
# Out:
# 0.9809203142536476

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size = 0.30,random_state=8)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.8097014925373134
